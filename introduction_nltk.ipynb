# %% [markdown]
# **Importando bibliotecas**
#
# Pra esse trabalho, vamos utilizar a biblioteca NLTK (Natural Language Toolkit) que possui ferramentas para realizar processamento simbólico e estatístico de linguagem natural.
#
#
# *   [Dcumentation NLTK - Natural Language Toolkit](https://www.nltk.org)
# *   [Natural Language Processing with Python Analyzing Text with the Natural Language Toolkit](https://www.nltk.org/book_1ed/)

# %%
import nltk
from nltk.corpus import floresta, genesis, machado, gutenberg
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.corpus import brown

# %% [markdown]
# Nessa etapa vamos fazer o download de todas as ferramentas que a NTLK disponibiliza.

# %%
nltk.download('all')

# %% [markdown]
# # Verificando os textos disponíveis para análise
#
# > A função fileids() descreve todos os titulos disponíveis na biblioteca

# %%
nltk.corpus.brown.fileids()

# %%
for i in nltk.corpus.gutenberg.fileids():
  print(i)
# Out:
# austen-emma.txt
# austen-persuasion.txt
# austen-sense.txt
# bible-kjv.txt
# blake-poems.txt
# bryant-stories.txt
# burgess-busterbrown.txt
# carroll-alice.txt
# chesterton-ball.txt
# chesterton-brown.txt
# chesterton-thursday.txt
# edgeworth-parents.txt
# melville-moby_dick.txt
# milton-paradise.txt
# shakespeare-caesar.txt
# shakespeare-hamlet.txt
# shakespeare-macbeth.txt
# whitman-leaves.txt

# %%
for i in nltk.corpus.webtext.fileids():
  print(i)
# Out:
# firefox.txt
# grail.txt
# overheard.txt
# pirates.txt
# singles.txt
# wine.txt

# %%
print(nltk.corpus.machado.readme())
# Out:
# Machado de Assis -- Obra Completa
#
# http://machado.mec.gov.br/
#
# Public Domain
#
# Contents:
#
# Romance
#
# romance/marm01.txt: Ressurreição (1872)
# romance/marm02.txt: A Mão e a Luva (1874)
# romance/marm03.txt: Helena (1876)
# romance/marm04.txt: Iaiá Garcia (1878)
# romance/marm05.txt: Memórias Póstumas de Brás Cubas (1881)
# romance/marm06.txt: Casa Velha (1885)
# romance/marm07.txt: Quincas Borba (1891)
# romance/marm08.txt: Dom Casmurro (1899)
# romance/marm09.txt: Esaú e Jacó (1904)
# romance/marm10.txt: Memorial de Aires (1908)
#
# Poesia
#
# poesia/maps01.txt: Crisálidas (1864)
# poesia/maps02.txt: Falenas (1870)
# poesia/maps03.txt: Americanas (1875)
# poesia/maps04.txt: Gazeta de Holanda (1886-88)
# poesia/maps05.txt: Ocidentais (1901)
# poesia/maps06.txt: O Almada (1908)
# poesia/maps07.txt: Dispersas (1854-1939)
#
# Contos
#
# ...

# %%
for i in nltk.corpus.machado.fileids():
  print(i)
# Out:
# contos/macn001.txt
# contos/macn002.txt
# contos/macn003.txt
# contos/macn004.txt
# contos/macn005.txt
# contos/macn006.txt
# contos/macn007.txt
# contos/macn008.txt
# contos/macn009.txt
# contos/macn010.txt
# contos/macn011.txt
# contos/macn012.txt
# contos/macn013.txt
# contos/macn014.txt
# contos/macn015.txt
# contos/macn016.txt
# contos/macn017.txt
# contos/macn018.txt
# contos/macn019.txt
# contos/macn020.txt
# contos/macn021.txt
# contos/macn022.txt
# contos/macn023.txt
# contos/macn024.txt
# contos/macn025.txt
# contos/macn026.txt
# contos/macn027.txt
# contos/macn028.txt
# contos/macn029.txt
# contos/macn030.txt
# contos/macn031.txt
# contos/macn032.txt
# contos/macn033.txt
# contos/macn034.txt
# contos/macn035.txt
# contos/macn036.txt
# contos/macn037.txt
# contos/macn038.txt
# contos/macn039.txt
# contos/macn040.txt
# contos/macn041.txt
# contos/macn042.txt
# contos/macn043.txt
# contos/macn044.txt
# contos/macn045.txt
# contos/macn046.txt
# contos/macn047.txt
# ...

# %%
print(nltk.corpus.machado.fileids())
# Out:
# ['contos/macn001.txt', 'contos/macn002.txt', 'contos/macn003.txt', 'contos/macn004.txt', 'contos/macn005.txt', 'contos/macn006.txt', 'contos/macn007.txt', 'contos/macn008.txt', 'contos/macn009.txt', 'contos/macn010.txt', 'contos/macn011.txt', 'contos/macn012.txt', 'contos/macn013.txt', 'contos/macn014.txt', 'contos/macn015.txt', 'contos/macn016.txt', 'contos/macn017.txt', 'contos/macn018.txt', 'contos/macn019.txt', 'contos/macn020.txt', 'contos/macn021.txt', 'contos/macn022.txt', 'contos/macn023.txt', 'contos/macn024.txt', 'contos/macn025.txt', 'contos/macn026.txt', 'contos/macn027.txt', 'contos/macn028.txt', 'contos/macn029.txt', 'contos/macn030.txt', 'contos/macn031.txt', 'contos/macn032.txt', 'contos/macn033.txt', 'contos/macn034.txt', 'contos/macn035.txt', 'contos/macn036.txt', 'contos/macn037.txt', 'contos/macn038.txt', 'contos/macn039.txt', 'contos/macn040.txt', 'contos/macn041.txt', 'contos/macn042.txt', 'contos/macn043.txt', 'contos/macn044.txt', 'contos/macn045.txt', 'contos
# ...

# %%
for i in nltk.corpus.machado.fileids():
  print(i)
# Out:
# ['contos/macn001.txt', 'contos/macn002.txt', 'contos/macn003.txt', 'contos/macn004.txt', 'contos/macn005.txt', 'contos/macn006.txt', 'contos/macn007.txt', 'contos/macn008.txt', 'contos/macn009.txt', 'contos/macn010.txt', 'contos/macn011.txt', 'contos/macn012.txt', 'contos/macn013.txt', 'contos/macn014.txt', 'contos/macn015.txt', 'contos/macn016.txt', 'contos/macn017.txt', 'contos/macn018.txt', 'contos/macn019.txt', 'contos/macn020.txt', 'contos/macn021.txt', 'contos/macn022.txt', 'contos/macn023.txt', 'contos/macn024.txt', 'contos/macn025.txt', 'contos/macn026.txt', 'contos/macn027.txt', 'contos/macn028.txt', 'contos/macn029.txt', 'contos/macn030.txt', 'contos/macn031.txt', 'contos/macn032.txt', 'contos/macn033.txt', 'contos/macn034.txt', 'contos/macn035.txt', 'contos/macn036.txt', 'contos/macn037.txt', 'contos/macn038.txt', 'contos/macn039.txt', 'contos/macn040.txt', 'contos/macn041.txt', 'contos/macn042.txt', 'contos/macn043.txt', 'contos/macn044.txt', 'contos/macn045.txt', 'contos
# ...

# %% [markdown]
# # Verificando detalhadamente as obras disponíveis para análise
#
# > A função readme() descreve todos as obras disponíveis na biblioteca

# %%
# Machado de Assis - Obra Completa
print(machado.readme())
# Out:
# Machado de Assis -- Obra Completa
#
# http://machado.mec.gov.br/
#
# Public Domain
#
# Contents:
#
# Romance
#
# romance/marm01.txt: Ressurreição (1872)
# romance/marm02.txt: A Mão e a Luva (1874)
# romance/marm03.txt: Helena (1876)
# romance/marm04.txt: Iaiá Garcia (1878)
# romance/marm05.txt: Memórias Póstumas de Brás Cubas (1881)
# romance/marm06.txt: Casa Velha (1885)
# romance/marm07.txt: Quincas Borba (1891)
# romance/marm08.txt: Dom Casmurro (1899)
# romance/marm09.txt: Esaú e Jacó (1904)
# romance/marm10.txt: Memorial de Aires (1908)
#
# Poesia
#
# poesia/maps01.txt: Crisálidas (1864)
# poesia/maps02.txt: Falenas (1870)
# poesia/maps03.txt: Americanas (1875)
# poesia/maps04.txt: Gazeta de Holanda (1886-88)
# poesia/maps05.txt: Ocidentais (1901)
# poesia/maps06.txt: O Almada (1908)
# poesia/maps07.txt: Dispersas (1854-1939)
#
# Contos
#
# ...

# %% [markdown]
# # Acessando uma obra do Machado de Assis

# %%
obra_machado = machado.raw('contos/macn001.txt')

# %%
print(obra_machado)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
shakerspeare_caesar = gutenberg.raw('shakespeare-caesar.txt')

# %%
type(shakerspeare_caesar)
# Out:
# str

# %%
print(shakerspeare_caesar)

# %%
shakerspeare_caesar = shakerspeare_caesar.lower()

# %%
print(shakerspeare_caesar)

# %%
english_stopwords = stopwords.words('english')

# %%
english_stopwords

# %%
import string
for i in string.punctuation:
  shakerspeare_caesar = shakerspeare_caesar.replace(i, '')

# %%
print(shakerspeare_caesar)

# %%
_shakerspeare_caesar = shakerspeare_caesar.replace('\n', ' ').split(' ')

# %%
no_stopwords = [words for words in _shakerspeare_caesar if words not in english_stopwords]

# %%
no_stopwords
# Out:
# ['tragedie',
#  'julius',
#  'caesar',
#  'william',
#  'shakespeare',
#  '1599',
#  '',
#  '',
#  'actus',
#  'primus',
#  'scoena',
#  'prima',
#  '',
#  'enter',
#  'flauius',
#  'murellus',
#  'certaine',
#  'commoners',
#  'ouer',
#  'stage',
#  '',
#  '',
#  '',
#  'flauius',
#  'hence',
#  'home',
#  'idle',
#  'creatures',
#  'get',
#  'home',
#  'holiday',
#  'know',
#  'mechanicall',
#  'ought',
#  'walke',
#  'vpon',
#  'labouring',
#  'day',
#  'without',
#  'signe',
#  'profession',
#  'speake',
#  'trade',
#  'art',
#  'thou',
#  '',
#  '',
#  'car',
#  'sir',
#  'carpenter',
#  '',
#  '',
#  '',
#  '',
#  'mur',
#  'thy',
#  'leather',
#  'apron',
#  'thy',
#  'rule',
#  'dost',
#  'thou',
#  'thy',
#  'best',
#  'apparrell',
#  'sir',
#  'trade',
#  '',
#  '',
#  'cobl',
#  'truely',
#  'sir',
#  'respect',
#  'fine',
#  'workman',
#  'would',
#  'say',
#  'cobler',
#  '',
#  '',
#  '',
#  '',
#  'mur',
#  'trade',
#  'art',
#  'thou',
#  'answer',
#  'directly',
# ...

# %% [markdown]
# # Teste

# %%
import os, re
from google.colab import drive

# %%
english_stopwords = stopwords.words('english')

# %%
def processing_text(str_text, _stopwords):
  text_format = re.findall(r'\b[A-zÀ-úü]+\b', str_text.lower())

  if _stopwords:
    no_stopwords = [words for words in text_format if words not in _stopwords and not len(words) == 1]
  else:
    no_stopwords = text_format

  return(' '.join(no_stopwords))

# %%
#drive.mount('/content/drive')
_path_books_drive = '/content/drive/MyDrive/Harry_Potter/'

list_books_hp = sorted(os.listdir(_path_books_drive))

list_books_hp
# Out:
# ["Book 1 - The Philosopher's Stone.txt",
#  'Book 2 - The Chamber of Secrets.txt',
#  'Book 3 - The Prisoner of Azkaban.txt',
#  'Book 4 - The Goblet of Fire.txt',
#  'Book 5 - The Order of the Phoenix.txt',
#  'Book 6 - The Half Blood Prince.txt',
#  'Book 7 - The Deathly Hallows.txt']

# %%
books_hp_no_processed = []
books_hp_processed = []

count = 1

book_hp = ''

for book in list_books_hp:
  if count == 1:
    with open(_path_books_drive + book, encoding='utf8') as f:
      _book = ''
      for line in f:
        if not line.startswith("Page |"):
          _book += line

    count = count + 1
    
    # books_hp_no_processed.append(_book)
    books_hp_processed.append(processing_text(_book, english_stopwords))
books_hp_processed
# Out:
# ['boy lived mr mrs dursley number four privet drive proud say perfectly normal thank much last people expect involved anything strange mysterious hold nonsense mr dursley director firm called grunnings made drills big beefy man hardly neck although large mustache mrs dursley thin blonde nearly twice usual amount neck came useful spent much time craning garden fences spying neighbors dursley small son called dudley opinion finer boy anywhere dursleys everything wanted also secret greatest fear somebody would discover think could bear anyone found potters mrs potter mrs dursley sister met several years fact mrs dursley pretended sister sister good nothing husband undursleyish possible dursleys shuddered think neighbors would say potters arrived street dursleys knew potters small son never even seen boy another good reason keeping potters away want dudley mixing child like mr mrs dursley woke dull gray tuesday story starts nothing cloudy sky outside suggest strange mysterious things wou
# ...

# %%
print(brown.categories())
# Out:
# ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']

# %%
words_mystery = brown.words(categories='mystery')

# %%
for i in words_mystery[0:100]:
    print(i)
# Out:
# There
# were
# thirty-eight
# patients
# on
# the
# bus
# the
# morning
# I
# left
# for
# Hanover
# ,
# most
# of
# them
# disturbed
# and
# hallucinating
# .
# An
# interne
# ,
# a
# nurse
# and
# two
# attendants
# were
# in
# charge
# of
# us
# .
# I
# felt
# lonely
# and
# depressed
# as
# I
# stared
# out
# the
# bus
# window
# at
# Chicago's
# grim
# ,
# dirty
# West
# Side
# .
# It
# seemed
# incredible
# ,
# as
# I
# listened
# to
# the
# monotonous
# drone
# of
# voices
# and
# smelled
# the
# fetid
# odors
# coming
# from
# the
# patients
# ,
# that
# technically
# I
# was
# a
# ward
# of
# the
# state
# of
# Illinois
# ,
# going
# to
# a
# hospital
# for
# the
# mentally
# ill
# .
# I
